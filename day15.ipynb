# %%
# day15 - https://adventofcode.com/2019/day/15

# %%
# this object is where the Intcode program lives and some useful methods
# to fill it, clear it, read from it, write to it
class Computer:
    import logging
    global set_trace
    global inputs
    global outputs
    
    def __init__(self, size, stage, rbase=0):
        # size is array size[0] = program memory, size[1] = general memory
        self.size = size  # must specify the memory size
        self.stage = stage
        # self.storage = [None] * (size[0] + size[1])  # initialize with None
        self.storage = [0] * (size[0] + size[1])  # initialize with 0s
        # initial relative_base
        self.rbase = rbase
        # program base memory is 0
        self.prog_base = 0
        # memory space is immediately above the programming space
        self.mem_base = size[0] + 1
        self.inputs = None
        self.outputs = None
    
    # set the releative_base value
    def set_rbase(self, val):
        self.rbase = val
        return
        
    # dump out the contents between 2 positions (defaults all the memory)
    def dump(self,start=0,end=-1):
        if(end == -1):
            end = self.size
        for i in range(start, end):
            print("{}: {}".format(i,self.storage[i]))

    # fill the memory with a sequence, starting at a certain position - which defaults to 0
    def fill(self, codelist, start_pos = 0):
        i = start_pos
        for j in codelist:
            self.storage[i] = j
            i+=1
    
    # fill (write to) memory with a sequence, allowing direct or reference starting location
    def mode_fill(self, s, mem_location, mode):
        # mem_location: where to begin fill or to reference to begin
        # mode (0 - position, 1 - immediate, 2 - relative)
        if(set_trace): import pdb; pdb.set_trace()
        if(mode == '0' or mode == '2'):
            # these are positional references
            i = self.relative_location(self.read(mem_location), mode)
            for j in s:
                self.storage[i] = j
                i+=1
        elif(mode == '1'):
            # this is the direct reference
            i = mem_location
            for j in s:
                self.storage[i] = j
                i+=1

    # load the program into program space
    def load_program(self, s):
        self.mode_fill(s, self.prog_base, "1")
        return
                
    # get data from input_buffer for this stage
    # if it has 2 values, then it hasn't read in the amp_setting
    # that state will return the last value and remove it

#     def getfrominput(self):
#         if(len(inputs[self.stage].contents) > 1):
#             # pop a value off and return it
#             return(inputs[self.stage].contents.pop())
#         else:
#             # return just that last value but leave it
#             return(inputs[self.stage].contents[0])

    # get data from single input buffer
    def getfrominput(self):
        return(self.inputs)

    # put data to output_buffer for this stage (which is next stage's input)
    # put this output value into position [0] of that buffer (position [1] will have possible amp_setting)
#     def puttooutput(self, val):
#         logging.info("outputting: {} to stage: {}".format(val, next_stage(self.stage,5)))
#         inputs[next_stage(self.stage,5)].contents[0] = val
#         return

    # output to single output variable
    def puttooutput(self, val):
        # global outputs
        self.outputs = val
        # logging.info("in puttooutput(), outputs: {}".format(outputs))
        # print(outputs)
        return

    # takes an input and processes until there is an output
    def process_input(self, inp):
        global prog_ctr
        global ops_ctr
        global ops_max
        self.inputs = inp
        while(prog_ctr != "STOP" and ops_ctr < ops_max):
            # if(set_trace_main): import pdb; pdb.set_trace()
            # logging.info("prog_ctr: {}, ops_ctr: {}".format(prog_ctr, ops_ctr))
            prog_ctr = self.exec_seq(prog_ctr)
            # if there is something in the output, grab it, clear it,then return it
            if(self.outputs is not None):
                o = self.outputs
                self.outputs = None
                return(o)
            ops_ctr += 1
        return(prog_ctr)
    
    # read the contents from just one position
    def read(self, pos):
        return self.storage[pos]
   
    # return the value based on parameter mode
    def mode_read(self, pos, mode):
        if(set_trace): import pdb; pdb.set_trace()
        # mode: 0 - position, 1 - immediate, 2 - relative
        if(mode == '0' or mode == '2'):
            return int(self.storage[self.relative_location(self.read(pos), mode)])
        elif(mode == '1'):
            return int(self.read(pos))

    # clear the memory
    def clear(self):
        self.storage = [None] * self.size

    # return the location adjusted by relative_base, based on mode
    def relative_location(self, location_val, mode):
        # location - location value read from prog
        # mode - the parameter mode -'0': position, '2': relative
        logging.info("relative_location() - location_val: {}, mode: {}, self.rbase: {}".format(location_val, mode, self.rbase))
        return((location_val + self.rbase) if int(mode) else location_val)
        
    # this function will execute a single sequence (operator + subsequent operands and output location)
    def exec_seq(self, ctr):
        global set_trace
        # these string representations of opcodes are used in logging
        opcodes = {"00":"NOT-AN-OPCODE","99":"STOP","01":"ADD","02":"MULTIPLY","03":"INPUT","04":"OUTPUT","05":"JUMP-TRUE","06":"JUMP-FALSE","07":"LESS-THAN","08":"EQUALS-TO", "09":"ADJUST-RBASE"}
        # ctr - where to start
        # m - the memory object to work from
        # the first in the sequence is the 'enhnanced opcode' (includes 3 parameter modes in most significant position)
        # zero-pad to 5 - most significant 0 is implied
        enhanced_opcode = str(self.read(ctr)).zfill(5)
        # first 3 characters are the parameter modes
        pmodes = enhanced_opcode[:3]
        # last 2 characters are the opcode
        opcode = enhanced_opcode[3:]
        if(set_trace): import pdb; pdb.set_trace()
        # ===================   99   -  STOP  ============================= 
        if(opcode == '99'):
            prog_status[self.stage] = "STOP"
            logging.info("opcode: {} - {}".format(opcode, opcodes[opcode]))
            return("STOP")
        # ===================   01   -  ADD  ============================= 
        elif(opcode == "01"):
            if(set_trace): import pdb; pdb.set_trace()
            operand1 = self.mode_read(ctr+1, pmodes[2])
            operand2 = self.mode_read(ctr+2, pmodes[1])
            if(set_trace): import pdb; pdb.set_trace()
            calcval = operand1 + operand2
        # ===================   02   -  MULTIPLY  ============================= 
        elif(opcode == "02"):
            if(set_trace): import pdb; pdb.set_trace()
            operand1 = self.mode_read(ctr+1, pmodes[2])
            operand2 = self.mode_read(ctr+2, pmodes[1])
            calcval = operand1 * operand2
        # ===================   03   -  INPUT  ============================= 
        elif(opcode == "03"):
            if(set_trace): import pdb; pdb.set_trace()
            # get the input
            # val = getfrominput()
            # the input buffer is the one for this amp stage
            val = self.getfrominput()
            # store it in address provided by next code
            self.mode_fill([val], ctr+1, pmodes[2])
            # return next prog counter
            logging.info("opcode: {}-{}, pmodes: {}, from-input: {}, @ctr+1: {}, ctr in: {}, returning: {}".format(opcode,opcodes[opcode],pmodes,val,self.read(ctr+1),ctr,ctr+2))
            return(ctr+2)
        # ===================   04   -  OUTPUT  ============================= 
        elif(opcode == "04"):
            if(set_trace): import pdb; pdb.set_trace()
            # read the val (based on mode) specified from next code and send to output
            self.puttooutput(self.mode_read(ctr+1, pmodes[2]))
            prog_status[self.stage] = "OUTPUT"
            logging.info("opcode: {}-{}, pmodes: {}, @ctr+1: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1),ctr,ctr+2))
            return(ctr+2)
        # ===================   05   -  JUMP-IF-TRUE  ============================= 
        elif(opcode == "05"):
            val_to_test = self.mode_read(ctr+1, pmodes[2])
            if(val_to_test):
                ret_ctr = self.mode_read(ctr+2, pmodes[1])
            else:
                ret_ctr = ctr+3
            logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, val_to_test: {}, ctr+2: {}, ctr+3: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1),val_to_test, self.read(ctr+2), self.read(ctr+3), ctr, ret_ctr))
            return(ret_ctr)
        # ===================   06   -  JUMP-IF-FALSE  ============================= 
        elif(opcode == "06"):
            val_to_test = self.mode_read(ctr+1, pmodes[2])
            if(val_to_test):
                ret_ctr = ctr+3
            else:
                ret_ctr = self.mode_read(ctr+2, pmodes[1])
            logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, val_to_test: {}, ctr+2: {}, ctr+3: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1),val_to_test, self.read(ctr+2), self.read(ctr+3), ctr, ret_ctr))
            return(ret_ctr)
        # ===================   07   -  LESS-THAN  ============================= 
        elif(opcode == "07"):
            operand1 = self.mode_read(ctr+1, pmodes[2])
            operand2 = self.mode_read(ctr+2, pmodes[1])
            if(operand1 < operand2):
                calcval = 1
            #    logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, ctr+2: {}, ctr+3: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1), self.read(ctr+2), self.read(ctr+3), ctr, ret_ctr))
            else:
                calcval = 0
            #    logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, ctr+2: {}, ctr+3: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1), self.read(ctr+2), self.read(ctr+3), ctr, ret_ctr))

        # ===================   08   -  EQUALS-TO  ============================= 
        elif(opcode == "08"):
            operand1 = self.mode_read(ctr+1, pmodes[2])
            operand2 = self.mode_read(ctr+2, pmodes[1])
            if(operand1 == operand2):
                calcval = 1
            else:
                calcval = 0
        # ===================   09   -  ADJUST-RELATIVE-BASE  ============================= 
        elif(opcode == "09"):
             # modify rbase by the value in next position
            self.rbase = self.rbase + self.mode_read(ctr+1, pmodes[2])
            logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, self.rbase: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1),self.rbase,ctr,ctr+2))
            return(ctr+2)
        # ===================   ?? - NOT KNOWN  ============================= 
        else:
            prog_status[self.stage] = "BADOPCODE"
            logging.info("opcode: {}-{}".format(opcode,opcodes[opcode]))
            return("BADOPCODE")
        # 3-parameter instructions get here
        # fill the output destination with value depending on mode
        if(set_trace): import pdb; pdb.set_trace()
        self.mode_fill([calcval], ctr+3, pmodes[0])
        logging.info("opcode: {}-{}, pmodes: {}, ctr+1: {}, op1: {}, ctr+2: {}, op2: {}, calcval: {}, ctr+3: {}, ctr in: {}, returning: {}".format(opcode, opcodes[opcode],pmodes,self.read(ctr+1),operand1,self.read(ctr+2),operand2,calcval,self.read(ctr+3),ctr,ctr+4))
        # and return the next postion in the memory
        return(ctr+4)

# %%
class pad:
    def __init__(self, loc, content):
        self.loc = loc
        self.content = content
        return
    
class World:
    def __init__(self, seq):
        self.pads = []
        self.comp = Computer([len(seq)*4,8000], 0)
        self.comp.load_program(seq)
        return

# %%
# given a position tuple, this returns the position tuple from the input_dir (1-north, 2-south, ...)
def next_pos(pos, input_dir):
    inc = [(0,1), (0,-1), (-1,0), (1,0)]
    return((pos[0] + inc[input_dir-1][0], pos[1] + inc[input_dir-1][1]))

# %%
# this returns the move command that is ccw from a bearing
# basically the next move command in the ccw list
def ccw_dir(bearing):
    # bearing - same as move command orientation (1-north, 3-west, 2-south, 4-east))
    global ccw_seq
    i = ccw_seq.index(bearing)
    n = i + 1
    if(n == 4):
        n = 0
    return(ccw_seq[n])

# this will return the reverse direction
def reverse_dir(bearing):
    return(ccw_dir(ccw_dir(bearing)))
# this will return the clockwise direction
def cw_dir(bearing):
    return(ccw_dir(ccw_dir(ccw_dir(bearing))))

# %%
# ccw sequence of move commands (1-north, 3-west, 2-south, 4-east)
ccw_seq = [1,3,2,4]
inputs = None
outputs = None
prog_status = [None] * 1

# %%
# run parameters / programs
run_name = "day15"

# read the sequence / prog from a file
ifn = "day15-input.txt"
d = open(ifn)
s = d.read()
# make a list of integers from the input comma-separated strings
seq = [int(j) for j in s.split(',')]

# %%
prog_ctr = 0
set_trace = False
set_trace_main = False
# this will reign in a prog in some crazy processing loop
ops_max = 10000
ops_ctr = 0

# %%
# this is used for logging
import time
year, month, day, hour, minute = time.strftime("%Y %m %d %H %M").split()
# log file name
lfn = "{}-{}{}{}{}{}.log".format(run_name,year,month,day,hour,minute)
# set up the logging
import logging
logging.basicConfig(filename=lfn, level=logging.ERROR)
logging.info("==============================================================================")

# %%
# initialize computer
# size array is [prog_space, memory_space]
# comp = Computer([len(seq)*2,4000], 0)

# %%
# load the program
# comp.load_program(seq)

# %%
w = World(seq)

current_loc = (0,0)
w.pads.append(pad(current_loc, 1))

# %%
# first command is 1-north
inputs = 1
bearing = 1
new_pad = False

# %%
def survey(home):
    global pads
    # go around all directions
    for i in range(1,5):
        pass
        return

# %%
# put in inputs until a bad entry or the oxygen filter is found, or a key input is entered
look_step = 1
max_pads = 300
while(outputs != "STOP" and outputs != 2 and len(w.pads) < max_pads):
    # get the output for the input
    outputs = w.comp.process_input(inputs)
    print("input: {}, output: {}, look_step: {}, current_loc: {}".format(inputs, outputs, look_step, current_loc))
    if(outputs not in ["STOP", 0, 1, 2]):
        print("something not right.")
        input()
    # the location for the move command
    test_loc = next_pos(current_loc, inputs)
    # if that location is new, store it in pads array
    if(len([p.content for p in w.pads if p.loc == test_loc]) == 0):
        w.pads.append(pad(test_loc, outputs))
        print("NEW!: {}-{}".format(test_loc, outputs))
        new_pad = True
    else:
        new_pad = False
    # if the output is a wall or empty...
    if(outputs == 0 or outputs == 1):
        # u = int(input("anything else to let system run normally."))
        # output the current location and the results from that command
        # print("from {}, bearing is: {}, movement command is: {} and output is: {}".format(current_loc, bearing, inputs, outputs))       
        # if the test location is a space, and is a new_pad
        if(outputs == 1 and (new_pad or look_step == 4)):
            # make it the current location (i.e. go to it)
            current_loc = test_loc
            bearing = inputs
            # next input command is ccw from current bearing
            inputs = ccw_dir(bearing)
            # if look_step = 4 just continue in the direction you came - which is the reverse of the 4th ccw rotation
            if( look_step == 4):
                inputs = reverse_dir(inputs)
            look_step = 1
        else:
            # here if last try was blocked (wall or been_there)
            look_step += 1
            # since blocked, adjust in clock-wise direction of last input
            inputs = cw_dir(inputs)
# Out:
# input: 1, output: 1, look_step: 1, current_loc: (0, 0)
# NEW!: (0, 1)-1
# input: 3, output: 0, look_step: 1, current_loc: (0, 1)
# NEW!: (-1, 1)-0
# input: 1, output: 1, look_step: 2, current_loc: (0, 1)
# NEW!: (0, 2)-1
# input: 3, output: 1, look_step: 1, current_loc: (0, 2)
# NEW!: (-1, 2)-1
# input: 2, output: 0, look_step: 1, current_loc: (-1, 2)
# input: 3, output: 1, look_step: 2, current_loc: (-1, 2)
# NEW!: (-2, 2)-1
# input: 2, output: 0, look_step: 1, current_loc: (-2, 2)
# NEW!: (-2, 1)-0
# input: 3, output: 0, look_step: 2, current_loc: (-2, 2)
# NEW!: (-3, 2)-0
# input: 1, output: 1, look_step: 3, current_loc: (-2, 2)
# NEW!: (-2, 3)-1
# input: 3, output: 0, look_step: 1, current_loc: (-2, 3)
# NEW!: (-3, 3)-0
# input: 1, output: 1, look_step: 2, current_loc: (-2, 3)
# NEW!: (-2, 4)-1
# input: 3, output: 1, look_step: 1, current_loc: (-2, 4)
# NEW!: (-3, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-3, 4)
# input: 3, output: 1, look_step: 2, current_loc: (-3, 4)
# NEW!: (-4, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-4, 4)
# NEW!: (-4, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-4, 4)
# NEW!: (-5, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-5, 4)
# NEW!: (-5, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-5, 4)
# NEW!: (-6, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-6, 4)
# NEW!: (-6, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-6, 4)
# NEW!: (-7, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-7, 4)
# NEW!: (-7, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-7, 4)
# NEW!: (-8, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-8, 4)
# NEW!: (-8, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-8, 4)
# NEW!: (-9, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-9, 4)
# NEW!: (-9, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-9, 4)
# NEW!: (-10, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-10, 4)
# NEW!: (-10, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-10, 4)
# NEW!: (-11, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-11, 4)
# NEW!: (-11, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-11, 4)
# NEW!: (-12, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-12, 4)
# NEW!: (-12, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-12, 4)
# NEW!: (-13, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-13, 4)
# NEW!: (-13, 3)-0
# input: 3, output: 1, look_step: 2, current_loc: (-13, 4)
# NEW!: (-14, 4)-1
# input: 2, output: 1, look_step: 1, current_loc: (-14, 4)
# NEW!: (-14, 3)-1
# input: 4, output: 0, look_step: 1, current_loc: (-14, 3)
# input: 2, output: 1, look_step: 2, current_loc: (-14, 3)
# NEW!: (-14, 2)-1
# input: 4, output: 0, look_step: 1, current_loc: (-14, 2)
# NEW!: (-13, 2)-0
# input: 2, output: 0, look_step: 2, current_loc: (-14, 2)
# NEW!: (-14, 1)-0
# input: 3, output: 1, look_step: 3, current_loc: (-14, 2)
# NEW!: (-15, 2)-1
# input: 2, output: 0, look_step: 1, current_loc: (-15, 2)
# NEW!: (-15, 1)-0
# input: 3, output: 1, look_step: 2, current_loc: (-15, 2)
# NEW!: (-16, 2)-1
# input: 2, output: 1, look_step: 1, current_loc: (-16, 2)
# NEW!: (-16, 1)-1
# input: 4, output: 0, look_step: 1, current_loc: (-16, 1)
# input: 2, output: 1, look_step: 2, current_loc: (-16, 1)
# NEW!: (-16, 0)-1
# input: 4, output: 0, look_step: 1, current_loc: (-16, 0)
# NEW!: (-15, 0)-0
# input: 2, output: 0, look_step: 2, current_loc: (-16, 0)
# NEW!: (-16, -1)-0
# input: 3, output: 1, look_step: 3, current_loc: (-16, 0)
# NEW!: (-17, 0)-1
# input: 2, output: 0, look_step: 1, current_loc: (-17, 0)
# NEW!: (-17, -1)-0
# input: 3, output: 1, look_step: 2, current_loc: (-17, 0)
# NEW!: (-18, 0)-1
# input: 2, output: 1, look_step: 1, current_loc: (-18, 0)
# NEW!: (-18, -1)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -1)
# input: 2, output: 1, look_step: 2, current_loc: (-18, -1)
# NEW!: (-18, -2)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -2)
# NEW!: (-17, -2)-0
# input: 2, output: 1, look_step: 2, current_loc: (-18, -2)
# NEW!: (-18, -3)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -3)
# NEW!: (-17, -3)-0
# input: 2, output: 1, look_step: 2, current_loc: (-18, -3)
# NEW!: (-18, -4)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -4)
# NEW!: (-17, -4)-0
# input: 2, output: 1, look_step: 2, current_loc: (-18, -4)
# NEW!: (-18, -5)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -5)
# NEW!: (-17, -5)-0
# input: 2, output: 1, look_step: 2, current_loc: (-18, -5)
# NEW!: (-18, -6)-1
# input: 4, output: 0, look_step: 1, current_loc: (-18, -6)
# NEW!: (-17, -6)-0
# input: 2, output: 0, look_step: 2, current_loc: (-18, -6)
# NEW!: (-18, -7)-0
# input: 3, output: 1, look_step: 3, current_loc: (-18, -6)
# NEW!: (-19, -6)-1
# input: 2, output: 0, look_step: 1, current_loc: (-19, -6)
# NEW!: (-19, -7)-0
# input: 3, output: 1, look_step: 2, current_loc: (-19, -6)
# NEW!: (-20, -6)-1
# input: 2, output: 0, look_step: 1, current_loc: (-20, -6)
# NEW!: (-20, -7)-0
# input: 3, output: 0, look_step: 2, current_loc: (-20, -6)
# NEW!: (-21, -6)-0
# input: 1, output: 1, look_step: 3, current_loc: (-20, -6)
# NEW!: (-20, -5)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, -5)
# NEW!: (-21, -5)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, -5)
# NEW!: (-20, -4)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, -4)
# NEW!: (-21, -4)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, -4)
# NEW!: (-20, -3)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, -3)
# NEW!: (-21, -3)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, -3)
# NEW!: (-20, -2)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, -2)
# NEW!: (-21, -2)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, -2)
# NEW!: (-20, -1)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, -1)
# NEW!: (-21, -1)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, -1)
# NEW!: (-20, 0)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, 0)
# NEW!: (-21, 0)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, 0)
# NEW!: (-20, 1)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, 1)
# NEW!: (-21, 1)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, 1)
# NEW!: (-20, 2)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, 2)
# NEW!: (-21, 2)-0
# input: 1, output: 0, look_step: 2, current_loc: (-20, 2)
# NEW!: (-20, 3)-0
# input: 4, output: 1, look_step: 3, current_loc: (-20, 2)
# NEW!: (-19, 2)-1
# input: 1, output: 0, look_step: 1, current_loc: (-19, 2)
# NEW!: (-19, 3)-0
# input: 4, output: 1, look_step: 2, current_loc: (-19, 2)
# NEW!: (-18, 2)-1
# input: 1, output: 1, look_step: 1, current_loc: (-18, 2)
# NEW!: (-18, 3)-1
# input: 3, output: 0, look_step: 1, current_loc: (-18, 3)
# input: 1, output: 1, look_step: 2, current_loc: (-18, 3)
# NEW!: (-18, 4)-1
# input: 3, output: 1, look_step: 1, current_loc: (-18, 4)
# NEW!: (-19, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-19, 4)
# input: 3, output: 1, look_step: 2, current_loc: (-19, 4)
# NEW!: (-20, 4)-1
# input: 2, output: 0, look_step: 1, current_loc: (-20, 4)
# input: 3, output: 0, look_step: 2, current_loc: (-20, 4)
# NEW!: (-21, 4)-0
# input: 1, output: 1, look_step: 3, current_loc: (-20, 4)
# NEW!: (-20, 5)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, 5)
# NEW!: (-21, 5)-0
# input: 1, output: 1, look_step: 2, current_loc: (-20, 5)
# NEW!: (-20, 6)-1
# input: 3, output: 0, look_step: 1, current_loc: (-20, 6)
# NEW!: (-21, 6)-0
# input: 1, output: 0, look_step: 2, current_loc: (-20, 6)
# NEW!: (-20, 7)-0
# input: 4, output: 1, look_step: 3, current_loc: (-20, 6)
# NEW!: (-19, 6)-1
# input: 1, output: 0, look_step: 1, current_loc: (-19, 6)
# NEW!: (-19, 7)-0
# input: 4, output: 1, look_step: 2, current_loc: (-19, 6)
# NEW!: (-18, 6)-1
# input: 1, output: 1, look_step: 1, current_loc: (-18, 6)
# NEW!: (-18, 7)-1
# input: 3, output: 0, look_step: 1, current_loc: (-18, 7)
# input: 1, output: 1, look_step: 2, current_loc: (-18, 7)
# NEW!: (-18, 8)-1
# input: 3, output: 0, look_step: 1, current_loc: (-18, 8)
# NEW!: (-19, 8)-0
# input: 1, output: 0, look_step: 2, current_loc: (-18, 8)
# NEW!: (-18, 9)-0
# input: 4, output: 1, look_step: 3, current_loc: (-18, 8)
# NEW!: (-17, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-17, 8)
# NEW!: (-17, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-17, 8)
# NEW!: (-16, 8)-1
# input: 1, output: 1, look_step: 1, current_loc: (-16, 8)
# NEW!: (-16, 9)-1
# input: 3, output: 0, look_step: 1, current_loc: (-16, 9)
# input: 1, output: 1, look_step: 2, current_loc: (-16, 9)
# NEW!: (-16, 10)-1
# input: 3, output: 0, look_step: 1, current_loc: (-16, 10)
# NEW!: (-17, 10)-0
# input: 1, output: 0, look_step: 2, current_loc: (-16, 10)
# NEW!: (-16, 11)-0
# input: 4, output: 1, look_step: 3, current_loc: (-16, 10)
# NEW!: (-15, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (-15, 10)
# NEW!: (-15, 11)-0
# input: 4, output: 1, look_step: 2, current_loc: (-15, 10)
# NEW!: (-14, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (-14, 10)
# NEW!: (-14, 11)-0
# input: 4, output: 0, look_step: 2, current_loc: (-14, 10)
# NEW!: (-13, 10)-0
# input: 2, output: 1, look_step: 3, current_loc: (-14, 10)
# NEW!: (-14, 9)-1
# input: 4, output: 0, look_step: 1, current_loc: (-14, 9)
# NEW!: (-13, 9)-0
# input: 2, output: 1, look_step: 2, current_loc: (-14, 9)
# NEW!: (-14, 8)-1
# input: 4, output: 1, look_step: 1, current_loc: (-14, 8)
# NEW!: (-13, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-13, 8)
# input: 4, output: 1, look_step: 2, current_loc: (-13, 8)
# NEW!: (-12, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-12, 8)
# NEW!: (-12, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-12, 8)
# NEW!: (-11, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-11, 8)
# NEW!: (-11, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-11, 8)
# NEW!: (-10, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-10, 8)
# NEW!: (-10, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-10, 8)
# NEW!: (-9, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-9, 8)
# NEW!: (-9, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-9, 8)
# NEW!: (-8, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-8, 8)
# NEW!: (-8, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-8, 8)
# NEW!: (-7, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-7, 8)
# NEW!: (-7, 9)-0
# input: 4, output: 1, look_step: 2, current_loc: (-7, 8)
# NEW!: (-6, 8)-1
# input: 1, output: 1, look_step: 1, current_loc: (-6, 8)
# NEW!: (-6, 9)-1
# input: 3, output: 0, look_step: 1, current_loc: (-6, 9)
# input: 1, output: 1, look_step: 2, current_loc: (-6, 9)
# NEW!: (-6, 10)-1
# input: 3, output: 0, look_step: 1, current_loc: (-6, 10)
# NEW!: (-7, 10)-0
# input: 1, output: 0, look_step: 2, current_loc: (-6, 10)
# NEW!: (-6, 11)-0
# input: 4, output: 1, look_step: 3, current_loc: (-6, 10)
# NEW!: (-5, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (-5, 10)
# NEW!: (-5, 11)-0
# input: 4, output: 1, look_step: 2, current_loc: (-5, 10)
# NEW!: (-4, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (-4, 10)
# NEW!: (-4, 11)-0
# input: 4, output: 0, look_step: 2, current_loc: (-4, 10)
# NEW!: (-3, 10)-0
# input: 2, output: 1, look_step: 3, current_loc: (-4, 10)
# NEW!: (-4, 9)-1
# input: 4, output: 0, look_step: 1, current_loc: (-4, 9)
# NEW!: (-3, 9)-0
# input: 2, output: 1, look_step: 2, current_loc: (-4, 9)
# NEW!: (-4, 8)-1
# input: 4, output: 1, look_step: 1, current_loc: (-4, 8)
# NEW!: (-3, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-3, 8)
# input: 4, output: 1, look_step: 2, current_loc: (-3, 8)
# NEW!: (-2, 8)-1
# input: 1, output: 0, look_step: 1, current_loc: (-2, 8)
# NEW!: (-2, 9)-0
# input: 4, output: 0, look_step: 2, current_loc: (-2, 8)
# NEW!: (-1, 8)-0
# input: 2, output: 1, look_step: 3, current_loc: (-2, 8)
# NEW!: (-2, 7)-1
# input: 4, output: 0, look_step: 1, current_loc: (-2, 7)
# NEW!: (-1, 7)-0
# input: 2, output: 1, look_step: 2, current_loc: (-2, 7)
# NEW!: (-2, 6)-1
# input: 4, output: 1, look_step: 1, current_loc: (-2, 6)
# NEW!: (-1, 6)-1
# input: 1, output: 0, look_step: 1, current_loc: (-1, 6)
# input: 4, output: 1, look_step: 2, current_loc: (-1, 6)
# NEW!: (0, 6)-1
# input: 1, output: 1, look_step: 1, current_loc: (0, 6)
# NEW!: (0, 7)-1
# input: 3, output: 0, look_step: 1, current_loc: (0, 7)
# input: 1, output: 1, look_step: 2, current_loc: (0, 7)
# NEW!: (0, 8)-1
# input: 3, output: 0, look_step: 1, current_loc: (0, 8)
# input: 1, output: 1, look_step: 2, current_loc: (0, 8)
# NEW!: (0, 9)-1
# input: 3, output: 0, look_step: 1, current_loc: (0, 9)
# NEW!: (-1, 9)-0
# input: 1, output: 1, look_step: 2, current_loc: (0, 9)
# NEW!: (0, 10)-1
# input: 3, output: 0, look_step: 1, current_loc: (0, 10)
# NEW!: (-1, 10)-0
# input: 1, output: 0, look_step: 2, current_loc: (0, 10)
# NEW!: (0, 11)-0
# input: 4, output: 1, look_step: 3, current_loc: (0, 10)
# NEW!: (1, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (1, 10)
# NEW!: (1, 11)-0
# input: 4, output: 1, look_step: 2, current_loc: (1, 10)
# NEW!: (2, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (2, 10)
# NEW!: (2, 11)-0
# input: 4, output: 1, look_step: 2, current_loc: (2, 10)
# NEW!: (3, 10)-1
# input: 1, output: 0, look_step: 1, current_loc: (3, 10)
# NEW!: (3, 11)-0
# input: 4, output: 1, look_step: 2, current_loc: (3, 10)
# NEW!: (4, 10)-1
# input: 1, output: 1, look_step: 1, current_loc: (4, 10)
# NEW!: (4, 11)-1
# input: 3, output: 0, look_step: 1, current_loc: (4, 11)
# input: 1, output: 1, look_step: 2, current_loc: (4, 11)
# NEW!: (4, 12)-1
# input: 3, output: 0, look_step: 1, current_loc: (4, 12)
# NEW!: (3, 12)-0
# input: 1, output: 1, look_step: 2, current_loc: (4, 12)
# NEW!: (4, 13)-1
# input: 3, output: 0, look_step: 1, current_loc: (4, 13)
# NEW!: (3, 13)-0
# input: 1, output: 1, look_step: 2, current_loc: (4, 13)
# NEW!: (4, 14)-1
# input: 3, output: 1, look_step: 1, current_loc: (4, 14)
# NEW!: (3, 14)-1
# input: 2, output: 0, look_step: 1, current_loc: (3, 14)
# input: 3, output: 1, look_step: 2, current_loc: (3, 14)
# NEW!: (2, 14)-1
# input: 2, output: 0, look_step: 1, current_loc: (2, 14)
# NEW!: (2, 13)-0
# input: 3, output: 0, look_step: 2, current_loc: (2, 14)
# NEW!: (1, 14)-0
# input: 1, output: 1, look_step: 3, current_loc: (2, 14)
# NEW!: (2, 15)-1
# input: 3, output: 0, look_step: 1, current_loc: (2, 15)
# NEW!: (1, 15)-0
# input: 1, output: 1, look_step: 2, current_loc: (2, 15)
# NEW!: (2, 16)-1
# input: 3, output: 0, look_step: 1, current_loc: (2, 16)
# NEW!: (1, 16)-0
# input: 1, output: 0, look_step: 2, current_loc: (2, 16)
# NEW!: (2, 17)-0
# input: 4, output: 1, look_step: 3, current_loc: (2, 16)
# NEW!: (3, 16)-1
# input: 1, output: 0, look_step: 1, current_loc: (3, 16)
# NEW!: (3, 17)-0
# input: 4, output: 1, look_step: 2, current_loc: (3, 16)
# NEW!: (4, 16)-1
# input: 1, output: 0, look_step: 1, current_loc: (4, 16)
# NEW!: (4, 17)-0
# input: 4, output: 1, look_step: 2, current_loc: (4, 16)
# NEW!: (5, 16)-1
# input: 1, output: 0, look_step: 1, current_loc: (5, 16)
# NEW!: (5, 17)-0
# input: 4, output: 1, look_step: 2, current_loc: (5, 16)
# NEW!: (6, 16)-1
# input: 1, output: 0, look_step: 1, current_loc: (6, 16)
# NEW!: (6, 17)-0
# input: 4, output: 1, look_step: 2, current_loc: (6, 16)
# NEW!: (7, 16)-1
# input: 1, output: 0, look_step: 1, current_loc: (7, 16)
# NEW!: (7, 17)-0
# input: 4, output: 1, look_step: 2, current_loc: (7, 16)
# NEW!: (8, 16)-1
# input: 1, output: 1, look_step: 1, current_loc: (8, 16)
# NEW!: (8, 17)-1
# input: 3, output: 0, look_step: 1, current_loc: (8, 17)
# input: 1, output: 1, look_step: 2, current_loc: (8, 17)
# NEW!: (8, 18)-1
# input: 3, output: 0, look_step: 1, current_loc: (8, 18)
# NEW!: (7, 18)-0
# input: 1, output: 1, look_step: 2, current_loc: (8, 18)
# NEW!: (8, 19)-1
# input: 3, output: 0, look_step: 1, current_loc: (8, 19)
# NEW!: (7, 19)-0
# input: 1, output: 1, look_step: 2, current_loc: (8, 19)
# NEW!: (8, 20)-1
# input: 3, output: 1, look_step: 1, current_loc: (8, 20)
# NEW!: (7, 20)-1
# input: 2, output: 0, look_step: 1, current_loc: (7, 20)
# input: 3, output: 1, look_step: 2, current_loc: (7, 20)
# NEW!: (6, 20)-1
# input: 2, output: 0, look_step: 1, current_loc: (6, 20)
# NEW!: (6, 19)-0
# input: 3, output: 1, look_step: 2, current_loc: (6, 20)
# NEW!: (5, 20)-1
# input: 2, output: 0, look_step: 1, current_loc: (5, 20)
# NEW!: (5, 19)-0
# input: 3, output: 1, look_step: 2, current_loc: (5, 20)
# NEW!: (4, 20)-1
# input: 2, output: 0, look_step: 1, current_loc: (4, 20)
# NEW!: (4, 19)-0
# input: 3, output: 1, look_step: 2, current_loc: (4, 20)
# NEW!: (3, 20)-1
# input: 2, output: 0, look_step: 1, current_loc: (3, 20)
# NEW!: (3, 19)-0
# input: 3, output: 1, look_step: 2, current_loc: (3, 20)
# NEW!: (2, 20)-1
# input: 2, output: 1, look_step: 1, current_loc: (2, 20)
# NEW!: (2, 19)-1
# input: 4, output: 0, look_step: 1, current_loc: (2, 19)
# input: 2, output: 1, look_step: 2, current_loc: (2, 19)
# NEW!: (2, 18)-1
# input: 4, output: 1, look_step: 1, current_loc: (2, 18)
# NEW!: (3, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (3, 18)
# input: 4, output: 1, look_step: 2, current_loc: (3, 18)
# NEW!: (4, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (4, 18)
# input: 4, output: 1, look_step: 2, current_loc: (4, 18)
# NEW!: (5, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (5, 18)
# input: 4, output: 1, look_step: 2, current_loc: (5, 18)
# NEW!: (6, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (6, 18)
# input: 4, output: 0, look_step: 2, current_loc: (6, 18)
# input: 2, output: 0, look_step: 3, current_loc: (6, 18)
# input: 3, output: 1, look_step: 4, current_loc: (6, 18)
# input: 1, output: 0, look_step: 1, current_loc: (5, 18)
# input: 4, output: 1, look_step: 2, current_loc: (5, 18)
# input: 2, output: 0, look_step: 3, current_loc: (5, 18)
# input: 3, output: 1, look_step: 4, current_loc: (5, 18)
# input: 1, output: 0, look_step: 1, current_loc: (4, 18)
# input: 4, output: 1, look_step: 2, current_loc: (4, 18)
# input: 2, output: 0, look_step: 3, current_loc: (4, 18)
# input: 3, output: 1, look_step: 4, current_loc: (4, 18)
# input: 1, output: 0, look_step: 1, current_loc: (3, 18)
# input: 4, output: 1, look_step: 2, current_loc: (3, 18)
# input: 2, output: 0, look_step: 3, current_loc: (3, 18)
# input: 3, output: 1, look_step: 4, current_loc: (3, 18)
# input: 1, output: 0, look_step: 1, current_loc: (2, 18)
# input: 4, output: 1, look_step: 2, current_loc: (2, 18)
# input: 2, output: 0, look_step: 3, current_loc: (2, 18)
# input: 3, output: 1, look_step: 4, current_loc: (2, 18)
# NEW!: (1, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (1, 18)
# NEW!: (1, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (1, 18)
# input: 2, output: 0, look_step: 3, current_loc: (1, 18)
# NEW!: (1, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (1, 18)
# NEW!: (0, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (0, 18)
# NEW!: (0, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (0, 18)
# input: 2, output: 0, look_step: 3, current_loc: (0, 18)
# NEW!: (0, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (0, 18)
# NEW!: (-1, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-1, 18)
# NEW!: (-1, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-1, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-1, 18)
# NEW!: (-1, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-1, 18)
# NEW!: (-2, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-2, 18)
# NEW!: (-2, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-2, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-2, 18)
# NEW!: (-2, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-2, 18)
# NEW!: (-3, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-3, 18)
# NEW!: (-3, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-3, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-3, 18)
# NEW!: (-3, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-3, 18)
# NEW!: (-4, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-4, 18)
# NEW!: (-4, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-4, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-4, 18)
# NEW!: (-4, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-4, 18)
# NEW!: (-5, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-5, 18)
# NEW!: (-5, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-5, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-5, 18)
# NEW!: (-5, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-5, 18)
# NEW!: (-6, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-6, 18)
# NEW!: (-6, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-6, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-6, 18)
# NEW!: (-6, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-6, 18)
# NEW!: (-7, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-7, 18)
# NEW!: (-7, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-7, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-7, 18)
# NEW!: (-7, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-7, 18)
# NEW!: (-8, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-8, 18)
# NEW!: (-8, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-8, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-8, 18)
# NEW!: (-8, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-8, 18)
# NEW!: (-9, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-9, 18)
# NEW!: (-9, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-9, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-9, 18)
# NEW!: (-9, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-9, 18)
# NEW!: (-10, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-10, 18)
# NEW!: (-10, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-10, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-10, 18)
# NEW!: (-10, 17)-0
# input: 3, output: 1, look_step: 4, current_loc: (-10, 18)
# NEW!: (-11, 18)-1
# input: 1, output: 0, look_step: 1, current_loc: (-11, 18)
# NEW!: (-11, 19)-0
# input: 4, output: 1, look_step: 2, current_loc: (-11, 18)
# input: 2, output: 0, look_step: 3, current_loc: (-11, 18)
# NEW!: (-11, 17)-0
# input: 3, output: 210, look_step: 4, current_loc: (-11, 18)
# something not right.

# %%
print("outputs: {}".format(outputs))

# %%
len(w.pads)

# %%
# for p in w.pads:
#     print("{} - {}".format(p.loc, p.content))
