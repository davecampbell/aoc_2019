# %%
# AOC - Day14 - Part 1 attempt: 2
# using testdata-02

# %%
import math

# %%
class Chemical:
    # need to do something special when this chemical is made
    # this is the ore, which gets mined, not made
    global o_str
    global ch
    def __init__(self, name, qty, rqty, reactants):
        self.name = name
        self.qty = qty
        self.rqty = rqty
        self.reactants = reactants
        return
    def make(self, req_qty):
        global ore_qty
        # if ore is being requested
        print("{}.make({})...".format(self.name, req_qty))
        if(self.name == o_str):
            # add this amount to accumulator
            ore_qty = ore_qty + req_qty
            # and return what is requested (instantly mined!)
            print("{} ORE mined! total so far: {}".format(req_qty, ore_qty))
            return(req_qty)
        # so ore not being requested.
        # see what is in inventory, and only kick off the reaction for what inventory can't provide
        need_amt = req_qty - self.qty
        if(need_amt <= 0):
            # have enough on hand.  reduce the inventory and return the requested amount.
            print("...enough on hand: {}".format(self.qty))
            self.qty -= req_qty
            return(req_qty)
        else:
            # determine factor required given need_amt and unit_quantity in the make reaction
            factor = calc_factor(need_amt, self.rqty)
            # now 'do the reaction' - iterate through the reactants
            for r in self.reactants:
                # get the ch array element for this reactant
                c = find_chem_by_name(ch, symnum(r)[0])
                req_amt = symnum(r)[1] * factor
                print("{} reactant: {} unit: {}, factor: {}, req_amt: {}, qty on-hand before make: {}".format(self.name, symnum(r)[0], symnum(r)[1], factor, req_amt, c.qty))
                made_amt = c.make(req_amt)
                # update on-hand leftover (req_amt is consumed in the calling reaction)
                c.qty = c.qty + made_amt - req_amt
                print("{} reactant: {} made_amt: {}, qty on-hand after make: {}".format(self.name, symnum(r)[0], made_amt, c.qty))
        return(factor*self.rqty)

# %%
class Reactant:
    def _init__(self, chem, qty):
        self.chem = chem
        self.qty = qty
        return

class Reaction:
    def __init__(self, reaction_tup):
        self.reactant_list = reaction_tup[0]
        self.product = reaction_tup[1]
        return

# %%
def parse_reaction(r_txt):
    # r_txt comes in like: "44 XJWVT, 5 KHKGT, 1 QDVJ, 29 NZVS, 9 GPVTF, 48 HKGWZ => 1 FUEL"
    # parse this out and return a reactant list (r_list) and product (p)
    # each looks like  {'CHEM_SYMBOL': NUMBER}
    r_list = []
    p = {}
    left, right = r_txt.split(" => ")
    p_num, p_chem = right.split()
    p[p_chem] = int(p_num)
    for l in left.split(", "):
        reactant = {}
        reactant[l.split()[1]] = int(l.split()[0])
        r_list.append(reactant)
    return(r_list, p)

# %%
def calc_factor(req, makeunit):
    return(int(math.ceil(req / makeunit)))

# %%
# this function returns the first key, value of a dictionary as a tuple
def symnum(r):
    sym = list(r.keys())[0]
    num = list(r.values())[0]
    return((sym, num))

# %%
def find_chem_by_name(ch, name):
    c = [chem for chem in ch if chem.name == name]
    return(c[0])

# %%
# array of chemicals
ch = []
ore_qty = 0
# these are the strings used for the chemical symbols for Fuel and Ore
f_str = "FUEL"
o_str = "ORE"

# %%
# read the reactions list from the input file
ifn = "day14-input-test-02.txt"
# parse each line
# each line defines a chemical and contains the reactancts
with open(ifn) as f:
    for line in f:
        r_list, p = parse_reaction(line)
        # create a chemical for the product and add it to the chemical array
        # initial quantity is 0, of course
        ch.append(Chemical(symnum(p)[0], 0, symnum(p)[1], r_list))
# add ore as a reaction (ore => ore)
o_reaction_line = "1 {} => 1 {}".format(o_str, o_str)
r_list, p = parse_reaction(o_reaction_line)
ch.append(Chemical(symnum(p)[0], 0, symnum(p)[1], r_list))

# %%
# this will return the chemical element that is the fuel
x = find_chem_by_name(ch, f_str)

# %%
# this will invoke the making of 1 unit of fuel
a = x.make(1)
# Out:
# FUEL.make(1)...
# FUEL reactant: STKFG unit: 53, factor: 1, req_amt: 53, qty on-hand before make: 0
# STKFG.make(53)...
# STKFG reactant: VPVL unit: 2, factor: 53, req_amt: 106, qty on-hand before make: 0
# VPVL.make(106)...
# VPVL reactant: NVRVD unit: 17, factor: 14, req_amt: 238, qty on-hand before make: 0
# NVRVD.make(238)...
# NVRVD reactant: ORE unit: 139, factor: 60, req_amt: 8340, qty on-hand before make: 0
# ORE.make(8340)...
# 8340 ORE mined! total so far: 8340
# NVRVD reactant: ORE made_amt: 8340, qty on-hand after make: 0
# VPVL reactant: NVRVD made_amt: 240, qty on-hand after make: 2
# VPVL reactant: JNWZP unit: 3, factor: 14, req_amt: 42, qty on-hand before make: 0
# JNWZP.make(42)...
# JNWZP reactant: ORE unit: 144, factor: 6, req_amt: 864, qty on-hand before make: 0
# ORE.make(864)...
# 864 ORE mined! total so far: 9204
# JNWZP reactant: ORE made_amt: 864, qty on-hand after make: 0
# VPVL reactant: JNWZP made_amt: 42, qty on-hand after make: 0
# STKFG reactant: VPVL made_amt: 112, qty on-hand after make: 6
# STKFG reactant: FWMGM unit: 7, factor: 53, req_amt: 371, qty on-hand before make: 0
# FWMGM.make(371)...
# FWMGM reactant: VJHF unit: 22, factor: 75, req_amt: 1650, qty on-hand before make: 0
# VJHF.make(1650)...
# VJHF reactant: ORE unit: 176, factor: 275, req_amt: 48400, qty on-hand before make: 0
# ORE.make(48400)...
# 48400 ORE mined! total so far: 57604
# VJHF reactant: ORE made_amt: 48400, qty on-hand after make: 0
# FWMGM reactant: VJHF made_amt: 1650, qty on-hand after make: 0
# FWMGM reactant: MNCFX unit: 37, factor: 75, req_amt: 2775, qty on-hand before make: 0
# MNCFX.make(2775)...
# MNCFX reactant: ORE unit: 145, factor: 463, req_amt: 67135, qty on-hand before make: 0
# ORE.make(67135)...
# 67135 ORE mined! total so far: 124739
# MNCFX reactant: ORE made_amt: 67135, qty on-hand after make: 0
# FWMGM reactant: MNCFX made_amt: 2778, qty on-hand after make: 3
# STKFG reactant: FWMGM made_amt: 375, qty on-hand after make: 4
# STKFG reactant: CXFTF unit: 2, factor: 53, req_amt: 106, qty on-hand before make: 0
# CXFTF.make(106)...
# CXFTF reactant: NVRVD unit: 1, factor: 14, req_amt: 14, qty on-hand before make: 2
# NVRVD.make(14)...
# NVRVD reactant: ORE unit: 139, factor: 3, req_amt: 417, qty on-hand before make: 0
# ORE.make(417)...
# 417 ORE mined! total so far: 125156
# NVRVD reactant: ORE made_amt: 417, qty on-hand after make: 0
# CXFTF reactant: NVRVD made_amt: 12, qty on-hand after make: 0
# STKFG reactant: CXFTF made_amt: 112, qty on-hand after make: 6
# STKFG reactant: MNCFX unit: 11, factor: 53, req_amt: 583, qty on-hand before make: 3
# MNCFX.make(583)...
# MNCFX reactant: ORE unit: 145, factor: 97, req_amt: 14065, qty on-hand before make: 0
# ORE.make(14065)...
# 14065 ORE mined! total so far: 139221
# MNCFX reactant: ORE made_amt: 14065, qty on-hand after make: 0
# STKFG reactant: MNCFX made_amt: 582, qty on-hand after make: 2
# FUEL reactant: STKFG made_amt: 53, qty on-hand after make: 0
# FUEL reactant: MNCFX unit: 6, factor: 1, req_amt: 6, qty on-hand before make: 2
# MNCFX.make(6)...
# MNCFX reactant: ORE unit: 145, factor: 1, req_amt: 145, qty on-hand before make: 0
# ORE.make(145)...
# 145 ORE mined! total so far: 139366
# MNCFX reactant: ORE made_amt: 145, qty on-hand after make: 0
# FUEL reactant: MNCFX made_amt: 6, qty on-hand after make: 2
# FUEL reactant: VJHF unit: 46, factor: 1, req_amt: 46, qty on-hand before make: 0
# VJHF.make(46)...
# VJHF reactant: ORE unit: 176, factor: 8, req_amt: 1408, qty on-hand before make: 0
# ORE.make(1408)...
# 1408 ORE mined! total so far: 140774
# VJHF reactant: ORE made_amt: 1408, qty on-hand after make: 0
# FUEL reactant: VJHF made_amt: 48, qty on-hand after make: 2
# FUEL reactant: HVMC unit: 81, factor: 1, req_amt: 81, qty on-hand before make: 0
# HVMC.make(81)...
# HVMC reactant: MNCFX unit: 5, factor: 27, req_amt: 135, qty on-hand before make: 2
# MNCFX.make(135)...
# MNCFX reactant: ORE unit: 145, factor: 23, req_amt: 3335, qty on-hand before make: 0
# ORE.make(3335)...
# 3335 ORE mined! total so far: 144109
# MNCFX reactant: ORE made_amt: 3335, qty on-hand after make: 0
# HVMC reactant: MNCFX made_amt: 138, qty on-hand after make: 5
# HVMC reactant: RFSQX unit: 7, factor: 27, req_amt: 189, qty on-hand before make: 0
# RFSQX.make(189)...
# RFSQX reactant: VJHF unit: 1, factor: 48, req_amt: 48, qty on-hand before make: 2
# VJHF.make(48)...
# VJHF reactant: ORE unit: 176, factor: 8, req_amt: 1408, qty on-hand before make: 0
# ORE.make(1408)...
# 1408 ORE mined! total so far: 145517
# VJHF reactant: ORE made_amt: 1408, qty on-hand after make: 0
# RFSQX reactant: VJHF made_amt: 48, qty on-hand after make: 2
# RFSQX reactant: MNCFX unit: 6, factor: 48, req_amt: 288, qty on-hand before make: 5
# MNCFX.make(288)...
# MNCFX reactant: ORE unit: 145, factor: 48, req_amt: 6960, qty on-hand before make: 0
# ORE.make(6960)...
# 6960 ORE mined! total so far: 152477
# MNCFX reactant: ORE made_amt: 6960, qty on-hand after make: 0
# RFSQX reactant: MNCFX made_amt: 288, qty on-hand after make: 5
# HVMC reactant: RFSQX made_amt: 192, qty on-hand after make: 3
# HVMC reactant: FWMGM unit: 2, factor: 27, req_amt: 54, qty on-hand before make: 4
# FWMGM.make(54)...
# FWMGM reactant: VJHF unit: 22, factor: 10, req_amt: 220, qty on-hand before make: 2
# VJHF.make(220)...
# VJHF reactant: ORE unit: 176, factor: 37, req_amt: 6512, qty on-hand before make: 0
# ORE.make(6512)...
# 6512 ORE mined! total so far: 158989
# VJHF reactant: ORE made_amt: 6512, qty on-hand after make: 0
# FWMGM reactant: VJHF made_amt: 222, qty on-hand after make: 4
# FWMGM reactant: MNCFX unit: 37, factor: 10, req_amt: 370, qty on-hand before make: 5
# MNCFX.make(370)...
# MNCFX reactant: ORE unit: 145, factor: 61, req_amt: 8845, qty on-hand before make: 0
# ORE.make(8845)...
# 8845 ORE mined! total so far: 167834
# MNCFX reactant: ORE made_amt: 8845, qty on-hand after make: 0
# FWMGM reactant: MNCFX made_amt: 366, qty on-hand after make: 1
# HVMC reactant: FWMGM made_amt: 50, qty on-hand after make: 0
# HVMC reactant: VPVL unit: 2, factor: 27, req_amt: 54, qty on-hand before make: 6
# VPVL.make(54)...
# VPVL reactant: NVRVD unit: 17, factor: 6, req_amt: 102, qty on-hand before make: 0
# NVRVD.make(102)...
# NVRVD reactant: ORE unit: 139, factor: 26, req_amt: 3614, qty on-hand before make: 0
# ORE.make(3614)...
# 3614 ORE mined! total so far: 171448
# NVRVD reactant: ORE made_amt: 3614, qty on-hand after make: 0
# VPVL reactant: NVRVD made_amt: 104, qty on-hand after make: 2
# VPVL reactant: JNWZP unit: 3, factor: 6, req_amt: 18, qty on-hand before make: 0
# JNWZP.make(18)...
# JNWZP reactant: ORE unit: 144, factor: 3, req_amt: 432, qty on-hand before make: 0
# ORE.make(432)...
# 432 ORE mined! total so far: 171880
# JNWZP reactant: ORE made_amt: 432, qty on-hand after make: 0
# VPVL reactant: JNWZP made_amt: 21, qty on-hand after make: 3
# HVMC reactant: VPVL made_amt: 48, qty on-hand after make: 0
# HVMC reactant: CXFTF unit: 19, factor: 27, req_amt: 513, qty on-hand before make: 6
# CXFTF.make(513)...
# CXFTF reactant: NVRVD unit: 1, factor: 64, req_amt: 64, qty on-hand before make: 2
# NVRVD.make(64)...
# NVRVD reactant: ORE unit: 139, factor: 16, req_amt: 2224, qty on-hand before make: 0
# ORE.make(2224)...
# 2224 ORE mined! total so far: 174104
# NVRVD reactant: ORE made_amt: 2224, qty on-hand after make: 0
# CXFTF reactant: NVRVD made_amt: 64, qty on-hand after make: 2
# HVMC reactant: CXFTF made_amt: 512, qty on-hand after make: 5
# FUEL reactant: HVMC made_amt: 81, qty on-hand after make: 0
# FUEL reactant: CXFTF unit: 68, factor: 1, req_amt: 68, qty on-hand before make: 5
# CXFTF.make(68)...
# CXFTF reactant: NVRVD unit: 1, factor: 8, req_amt: 8, qty on-hand before make: 2
# NVRVD.make(8)...
# NVRVD reactant: ORE unit: 139, factor: 2, req_amt: 278, qty on-hand before make: 0
# ORE.make(278)...
# 278 ORE mined! total so far: 174382
# NVRVD reactant: ORE made_amt: 278, qty on-hand after make: 0
# CXFTF reactant: NVRVD made_amt: 8, qty on-hand after make: 2
# FUEL reactant: CXFTF made_amt: 64, qty on-hand after make: 1
# FUEL reactant: GNMV unit: 25, factor: 1, req_amt: 25, qty on-hand before make: 0
# GNMV.make(25)...
# GNMV reactant: VJHF unit: 5, factor: 5, req_amt: 25, qty on-hand before make: 4
# VJHF.make(25)...
# VJHF reactant: ORE unit: 176, factor: 4, req_amt: 704, qty on-hand before make: 0
# ORE.make(704)...
# 704 ORE mined! total so far: 175086
# VJHF reactant: ORE made_amt: 704, qty on-hand after make: 0
# GNMV reactant: VJHF made_amt: 24, qty on-hand after make: 3
# GNMV reactant: MNCFX unit: 7, factor: 5, req_amt: 35, qty on-hand before make: 1
# MNCFX.make(35)...
# MNCFX reactant: ORE unit: 145, factor: 6, req_amt: 870, qty on-hand before make: 0
# ORE.make(870)...
# 870 ORE mined! total so far: 175956
# MNCFX reactant: ORE made_amt: 870, qty on-hand after make: 0
# GNMV reactant: MNCFX made_amt: 36, qty on-hand after make: 2
# GNMV reactant: VPVL unit: 9, factor: 5, req_amt: 45, qty on-hand before make: 0
# VPVL.make(45)...
# VPVL reactant: NVRVD unit: 17, factor: 6, req_amt: 102, qty on-hand before make: 2
# NVRVD.make(102)...
# NVRVD reactant: ORE unit: 139, factor: 25, req_amt: 3475, qty on-hand before make: 0
# ORE.make(3475)...
# 3475 ORE mined! total so far: 179431
# NVRVD reactant: ORE made_amt: 3475, qty on-hand after make: 0
# VPVL reactant: NVRVD made_amt: 100, qty on-hand after make: 0
# VPVL reactant: JNWZP unit: 3, factor: 6, req_amt: 18, qty on-hand before make: 3
# JNWZP.make(18)...
# JNWZP reactant: ORE unit: 144, factor: 3, req_amt: 432, qty on-hand before make: 0
# ORE.make(432)...
# 432 ORE mined! total so far: 179863
# JNWZP reactant: ORE made_amt: 432, qty on-hand after make: 0
# VPVL reactant: JNWZP made_amt: 21, qty on-hand after make: 6
# GNMV reactant: VPVL made_amt: 48, qty on-hand after make: 3
# GNMV reactant: CXFTF unit: 37, factor: 5, req_amt: 185, qty on-hand before make: 1
# CXFTF.make(185)...
# CXFTF reactant: NVRVD unit: 1, factor: 23, req_amt: 23, qty on-hand before make: 0
# NVRVD.make(23)...
# NVRVD reactant: ORE unit: 139, factor: 6, req_amt: 834, qty on-hand before make: 0
# ORE.make(834)...
# 834 ORE mined! total so far: 180697
# NVRVD reactant: ORE made_amt: 834, qty on-hand after make: 0
# CXFTF reactant: NVRVD made_amt: 24, qty on-hand after make: 1
# GNMV reactant: CXFTF made_amt: 184, qty on-hand after make: 0
# FUEL reactant: GNMV made_amt: 30, qty on-hand after make: 5

# %%
print("the amount of ore to create 1 fuel is: {}".format(ore_qty))
# Out:
# the amount of ore to create 1 fuel is: 180697
